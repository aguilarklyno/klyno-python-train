# %% [markdown]
# # 6章 物流の最適ルートをコンサルティングする１０本ノック
#
# ここでは、「物流」の基礎となる「輸送最適化」を検討するにあたっての基礎的な技術を習得します。
# 実際の物流データからネットワーク構造を可視化する方法について学び、最適な物流計画を立案する流れを学んでいきます。

# %% [markdown]
# ### ノック５１：物流に関するデータを読み込んでみよう

# %%
import pandas as pd

factories = pd.read_csv("tbl_factory.csv", index_col=0)
factories
# Out:
#         FCName  FCDemand FCRegion
# FCID
# FC00001   東京工場        28       関東
# FC00002  木更津工場        29       関東
# FC00003   多摩工場        31       関東
# FC00004  横須賀工場        25       関東
# FC00005   仙台工場        21       東北
# FC00006   山形工場        30       東北
# FC00007   那須工場        25       東北
# FC00008   青森工場        16       東北

# %%
warehouses = pd.read_csv("rel_cost.csv",index_col=0)
warehouses
# Out:
#             FCID     WHID  Cost
# RCostID
# 1        FC00001  WH00001   0.4
# 2        FC00001  WH00002   0.8
# 3        FC00001  WH00003   1.5
# 4        FC00002  WH00001   0.9
# 5        FC00002  WH00002   0.8
# 6        FC00002  WH00003   1.6
# 7        FC00003  WH00001   1.2
# 8        FC00003  WH00002   1.3
# 9        FC00003  WH00003   1.5
# 10       FC00004  WH00001   0.8
# 11       FC00004  WH00002   1.0
# 12       FC00004  WH00003   1.1
# 13       FC00005  WH00004   0.8
# 14       FC00005  WH00005   0.3
# 15       FC00005  WH00006   1.4
# 16       FC00006  WH00004   0.9
# 17       FC00006  WH00005   1.1
# 18       FC00006  WH00006   0.7
# 19       FC00007  WH00004   0.9
# 20       FC00007  WH00005   1.2
# 21       FC00007  WH00006   1.3
# 22       FC00008  WH00004   1.5
# 23       FC00008  WH00005   1.2
# 24       FC00008  WH00006   1.3

# %%
cost = pd.read_csv("rel_cost.csv", index_col=0)
cost.head()
# Out:
#             FCID     WHID  Cost
# RCostID
# 1        FC00001  WH00001   0.4
# 2        FC00001  WH00002   0.8
# 3        FC00001  WH00003   1.5
# 4        FC00002  WH00001   0.9
# 5        FC00002  WH00002   0.8

# %%
trans = pd.read_csv("tbl_transaction.csv", index_col=0)
trans.head()
# Out:
#           TransactionDate     ToFC   FromWH  Quantity
# TRID
# 0     2019-01-01 02:11:10  FC00004  WH00003        33
# 1     2019-01-01 06:12:42  FC00007  WH00006        19
# 2     2019-01-01 06:32:32  FC00006  WH00004        31
# 3     2019-01-01 07:17:06  FC00002  WH00003        18
# 4     2019-01-01 07:52:18  FC00001  WH00002        30

# %%
join_data = pd.merge(trans, cost, left_on=["ToFC", "FromWH"], right_on=["FCID", "WHID"], how="left")
join_data.head()
# Out:
#        TransactionDate     ToFC   FromWH  Quantity     FCID     WHID  Cost
# 0  2019-01-01 02:11:10  FC00004  WH00003        33  FC00004  WH00003   1.1
# 1  2019-01-01 06:12:42  FC00007  WH00006        19  FC00007  WH00006   1.3
# 2  2019-01-01 06:32:32  FC00006  WH00004        31  FC00006  WH00004   0.9
# 3  2019-01-01 07:17:06  FC00002  WH00003        18  FC00002  WH00003   1.6
# 4  2019-01-01 07:52:18  FC00001  WH00002        30  FC00001  WH00002   0.8

# %%
join_data = pd.merge(join_data, factories, left_on="ToFC", right_on="FCID", how="left")
join_data.head()
# Out:
#        TransactionDate     ToFC   FromWH  Quantity     FCID     WHID  Cost  \
# 0  2019-01-01 02:11:10  FC00004  WH00003        33  FC00004  WH00003   1.1
# 1  2019-01-01 06:12:42  FC00007  WH00006        19  FC00007  WH00006   1.3
# 2  2019-01-01 06:32:32  FC00006  WH00004        31  FC00006  WH00004   0.9
# 3  2019-01-01 07:17:06  FC00002  WH00003        18  FC00002  WH00003   1.6
# 4  2019-01-01 07:52:18  FC00001  WH00002        30  FC00001  WH00002   0.8
#
#   FCName  FCDemand FCRegion
# 0  横須賀工場        25       関東
# 1   那須工場        25       東北
# 2   山形工場        30       東北
# 3  木更津工場        29       関東
# 4   東京工場        28       関東

# %%
join_data = pd.merge(join_data, warehouses, left_on="FromWH", right_on="WHID", how="left")
join_data.head()
# Out:
#        TransactionDate     ToFC   FromWH  Quantity   FCID_x   WHID_x  Cost_x  \
# 0  2019-01-01 02:11:10  FC00004  WH00003        33  FC00004  WH00003     1.1
# 1  2019-01-01 02:11:10  FC00004  WH00003        33  FC00004  WH00003     1.1
# 2  2019-01-01 02:11:10  FC00004  WH00003        33  FC00004  WH00003     1.1
# 3  2019-01-01 02:11:10  FC00004  WH00003        33  FC00004  WH00003     1.1
# 4  2019-01-01 06:12:42  FC00007  WH00006        19  FC00007  WH00006     1.3
#
#   FCName  FCDemand FCRegion   FCID_y   WHID_y  Cost_y
# 0  横須賀工場        25       関東  FC00001  WH00003     1.5
# 1  横須賀工場        25       関東  FC00002  WH00003     1.6
# 2  横須賀工場        25       関東  FC00003  WH00003     1.5
# 3  横須賀工場        25       関東  FC00004  WH00003     1.1
# 4   那須工場        25       東北  FC00005  WH00006     1.4

# %%
join_data = join_data[["TransactionDate", "Quantity", "Cost", "ToFC", "FCName", "FCDemand", "FromWH", "WHName", "WHSupply", "WHRegion"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 join_data = join_data[["TransactionDate", "Quantity", "Cost", "ToFC", "FCName", "FCDemand", "FromWH", "WHName", "WHSupply", "WHRegion"]]
#
# File ~/opt/anaconda3/envs/kaggle_book/lib/python3.10/site-packages/pandas/core/frame.py:3810, in DataFrame.__getitem__(self, key)
#    3808     if is_iterator(key):
#    3809         key = list(key)
# -> 3810     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3812 # take() does not accept boolean indexers
#    3813 if getattr(indexer, "dtype", None) == bool:
#
# File ~/opt/anaconda3/envs/kaggle_book/lib/python3.10/site-packages/pandas/core/indexes/base.py:6111, in Index._get_indexer_strict(self, key, axis_name)
#    6108 else:
#    6109     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6111 self._raise_if_missing(keyarr, indexer, axis_name)
#    6113 keyarr = self.take(indexer)
#    6114 if isinstance(key, Index):
#    6115     # GH 42790 - Preserve name from an Index
#
# File ~/opt/anaconda3/envs/kaggle_book/lib/python3.10/site-packages/pandas/core/indexes/base.py:6174, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6171     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6173 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6174 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['WHName', 'WHSupply', 'WHRegion'] not in index"

# %% [markdown]
# ### ノック５２：現状の輸送量、コストを確認してみよう

# %% [markdown]
# ### ノック５３：ネットワークを可視化してみよう

# %% [markdown]
# ### ノック５４：ネットワークにノードを追加してみよう

# %% [markdown]
# ### ノック５５：ルートの重みづけを実施しよう

# %% [markdown]
# ### ノック５６：輸送ルート情報を読み込んでみよう

# %% [markdown]
# ### ノック５７：輸送ルート情報からネットワークを可視化してみよう

# %% [markdown]
# ### ノック５８：輸送コスト関数を作成しよう

# %% [markdown]
# ### ノック５９：制約条件を作ってみよう

# %% [markdown]
# ### ノック６０：輸送ルートを変更して、輸送コスト関数の変化を確認しよう
